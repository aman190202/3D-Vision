# %% [markdown]
# <a href="https://colab.research.google.com/github/ialhashim/DenseDepth/blob/master/DenseDepth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 298, done.
# remote: Total 298 (delta 0), reused 0 (delta 0), pack-reused 298
# Receiving objects: 100% (298/298), 12.14 MiB | 1.31 MiB/s, done.
# Resolving deltas: 100% (150/150), done.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2022-09-28 14:40:06--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.25.107
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.25.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M   379KB/s    in 8m 52s
#
# 2022-09-28 14:49:00 (317 KB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
# !cd DenseDepth; python test.py
# Out:
# Loading model...
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
#
#
# Model loaded (nyu.h5).
#
# Loaded (12) images of size (480, 640, 3).
# 6/6 [==============================] - 8s 721ms/step
# /Users/aman/Developer/3D-Vision/DenseDepth/utils.py:77: FutureWarning: `multichannel` is a deprecated argument name for `montage`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   return skimage.util.montage(all_images, multichannel=True, fill=(0,0,0))
# Figure(1000x500)

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )

# %%
# !cd DenseDepth/PyTorch; python test_pytorch.py
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )
# Out:
# /Users/aman/Developer/3D-Vision/env/bin/python: can't open file '/Users/aman/Developer/3D-Vision/DenseDepth/PyTorch/test_pytorch.py': [Errno 2] No such file or directory
